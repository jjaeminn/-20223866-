# %%
def ani_start():
    input("다음 중 당신이 선택한 동물의 특징이 반영된 번호를 고르세요: 시작하려면 아무거나 누르세요")

    Qfirst = int(input("1. 육지 생물 입니까?  2. 해양생물 입니까? : "))
    if Qfirst == 1:
        Qfirst_one = int(input("1. 양서류 입니까?   2. 조류 입니까?  3. 파충류 입니까?  4. 없습니까 ? "))
        if Qfirst_one == 1:
            Qfirst_one_one = int(input("1. 매끈매끈한 피부를 가진다.  2. 거칠거칠한 피부를 가진다"))
            if Qfirst_one_one == 1 :
                print("개구리")
            elif Qfirst_one_one == 2 :
                print("두꺼비")
        if Qfirst_one == 2:
            Qfirst_one_two = int(input("1. 몸색깔이 검정색이다  2. 우리 주변에서 매우 흔히 볼 수 있다.   3. 조류 중 최강의 포식자이다."))
            if Qfirst_one_two == 1:
                print('까마귀')
            elif Qfirst_one_two == 2:
                print('비둘기')
            elif Qfirst_one_two == 3:
                print('독수리')
        if Qfirst_one == 3:
            Qfirt_one_three = int(input("1. 독을 가지고 있을 수 있다.  2. 몸색깔을 변화 시킬 수 있다."))
            if Qfirt_one_three == 1:
                Qfirt_one_three_one = int(input(" 1. 몸이 길다 2. 꼬리가 없어져도 다시 생긴다."))
                if Qfirt_one_three_one == 1:
                    print("뱀")
                elif Qfirt_one_three_one == 2:
                    print("도마뱀")
            if Qfirt_one_three == 2:
                print("카멜레온")
        if Qfirst_one == 4:
            Qfirst_one_four = int(input("1. 대형 동물 입니까?   2. 소형 동물 입니까? "))
            if Qfirst_one_four == 1:
                Qfirst_one_four_one = int(input(" 1. 목이 길다.  2. 뿔이 있다.  3. 코가 길다. 4 조건에 없다."))
                if  Qfirst_one_four_one == 1:
                    print("기린")
                elif  Qfirst_one_four_one == 2:
                    print("코뿔소")
                elif  Qfirst_one_four_one  == 3:
                    print("기린")
                elif  Qfirst_one_four_one  == 4:
                    print("하마")
            if Qfirst_one_four == 2: 
                Qfirst_one_four_two = int(input("1. 독립적인 동물이다.  2. 주인에게 충성심이 높다."))
                if  Qfirst_one_four_two == 1:
                    print("고양이")
                elif  Qfirst_one_four_two == 2:
                    print("강아지")
    if Qfirst == 2:
        Qfirst_two = int(input("1. 강장동물 입니까?   2. 갑각류 입니까?   3. 극피동물 입니까?  4. 연체동물 입니까  5. 포유류 입니까? 6. 어류 입니까?"))
        if Qfirst_two == 1:
            Qfirst_two_one = int(input("1. 흰동가리와 공생관계이다.  2. 몸이 반투명색이다. "))
            if Qfirst_two_one == 1:
                  print("말미잘")
            elif Qfirst_two_one == 2: 
                    print("해파리")
        elif Qfirst_two == 2:
            Qfirst_two_two = int(input(" 1. 옆으로 움직인다. 2. 자유롭게 움직인다."))
            if  Qfirst_two_two == 1:
                  print("게")
            elif  Qfirst_two_two == 2:
                Qfirst_two_two_one = int(input("1. 집게가 있음.  2. 집게가 없음 "))
                if Qfirst_two_two_one == 1:
                          print("가재")
                elif Qfirst_two_two_one == 2:
                          print("새우")
        elif Qfirst_two == 3:
            Qfirst_two_three == int(input(" 1. 밤송이와 비슷하게 생겼다.  2. 잘라도 잘 안죽는다."))
            if Qfirst_two_three == 1:
                  print("성게")
            elif Qfirst_two_three == 2:
                Qfirst_two_three_one = int(input("1. 별모양이다. 2. 원기둥 반잘린 모양처럼 생겼다. "))
                if Qfirst_two_three_one == 1:
                      print("불가사리")
                elif Qfirst_two_three_one == 2:
                      print("해삼")
        elif Qfirst_two == 4:
            Qfirst_two_four = int(input("1. 다리가 8개이다. 2. 다리가 10개이다. "))
            if Qfirst_two_four == 1:
                  print("문어")
            elif Qfirst_two_four == 2:
                  print("오징어")
        elif Qfirst_two == 5:
            Qfirst_two_five = int(input("1. 송곳니가 두드러진다. 2. 현존 지구상에서 가장 큰 동물이다. 3. 서커스에서 흔히 볼 수 있고 지능이 높다고 알려져있다."))
            if Qfirst_two_five == 1:
                print("바다표범")
            elif Qfirst_two_five == 2:
                print("고래")
            elif Qfirst_two_five == 3:
                print("돌고래")
        elif Qfirst_two == 6:
            Qfist_two_six = int(input("1. 바다에 산다.  2. 민물에 산다."))
            if Qfirst_two_six == 1:
                print("참치")
            elif Qfirst_two_six == 2:
                Qfirst_two_six_one = int(input("1. 몸에 바늘이 크다. 2. 몸이 매끄럽다. 3. 수염이 두드러진다."))
                if Qfirst_two_six_one == 1:
                    print("잉어")
                elif Qfirst_two_six_one == 2:
                    print("미꾸라지")
                elif Qfirst_two_six_one == 3:
                    print("메기")


from tkinter import *

app = Tk()
app.title("동물 맞추기 프로그램 ")
animalClass = Label(app, text = "동물들 종류 : 까마귀, 비둘기 , 독수리 , 뱀, 도마뱀 , 카멜레온,기린, 코뿔소, 기린 ,하마 , 고양이,강아지, 말미잘, 해파리, 게, 가재 , 새우, 성게, 불가사리 ,해삼,문어, 오징어 ,바다표범 ,고래, 돌고래 ,참치 , 잉어, 미꾸라지, 메기") 
animalClass.pack()
start = Button(app, text = "시작", command = ani_start)
start.pack()
app.mainloop()
# Out:
# 까마귀

# %%
        input("앞에 것이 참이면 1, 뒤의 것 이 참이면 2번을 눌러주세요")

Qfirst = input(int("육지 생물 입니까?  1번입력) 해양생물 입니까 2번입력) : "))
if Qfirst == 1:
    print("육지 생물 입니다.")
print(Qfirst)
